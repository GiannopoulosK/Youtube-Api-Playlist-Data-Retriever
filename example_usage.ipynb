# %%
from googleapiclient.discovery import build
from api_functions import *
from preprocessing_functions import *

# Initialize API KEY
import os
api_key = os.environ.get('YOUTUBE-API-KEY')

# Convenient way to create the API functionality
api = build('youtube', 'v3', developerKey = api_key)

# %%
# Call the API and get the data
playlist_id = 'PLfoNZDHitwjX-oU5YVAkfuXkALZqempRS'
df = get_playlist_df(api, playlist_id=playlist_id)  

# Apply Preprocessing steps(optional)
df = preprocess_df(df)

# %%
df.head(10)
# Out:
#        VideoId                                            Title  \
# 0  f9j8nhMNYO4        Race Highlights | 2023 Bahrain Grand Prix
# 1  BxGpi0racMc  Race Highlights | 2023 Saudi Arabian Grand Prix
# 2  FExS3lFEwqc     Race Highlights | 2023 Australian Grand Prix
# 3  nJIrvbkr4pk     Race Highlights | 2023 Azerbaijan Grand Prix
# 4  2-jvlhc7c58          Race Highlights | 2023 Miami Grand Prix
# 5  JyBq7XYDiBg         Race Highlights | 2023 Monaco Grand Prix
# 6  Yd5FCI0JWMg        Race Highlights | 2023 Spanish Grand Prix
# 7  yX_GUhWiBHk       Race Highlights | 2023 Canadian Grand Prix
# 8  gzwm8hYryro       Race Highlights | 2023 Austrian Grand Prix
# 9  NxQT7GIkPLI        Race Highlights | 2023 British Grand Prix
#
#                                          Description  HD     Views   Likes  \
# 0  F1 is BACK! Watch all the best bits from our o...  hd  10234607  171221
# 1  Our third trip to the fast-flowing streets of ...  hd   8306076  129466
# 2  Our race in Melbourne did not disappoint! Catc...  hd  10375436  177185
# 3  It was all GO on the streets of Baku! Enjoy al...  hd   7556570  119297
# 4  Checo Perez started on pole, his team mate and...  hd   6650573  107014
# 5  A late rain shower made for a classic in Monte...  hd   7770352  120523
# 6  After topping every session in Barcelona so fa...  hd   5992150   99039
# 7  Lights out in Canada! Catch up on all the best...  hd   6124488  101470
# 8  Lights out in Austria for 71 quick laps around...  hd   5502066   91997
# 9  Max Verstappen started up on pole, searching f...  hd   5853286  105795
#
#   Favorites Comments      TopicCategories        Date      Time  TotalSeconds
# 0         0    10559  [Motorsport, Sport]  2023-03-05  17:16:32           470
# 1         0     6427  [Motorsport, Sport]  2023-03-19  19:37:50           494
# 2         0     8962  [Motorsport, Sport]  2023-04-02  09:02:53           495
# 3         0     4788  [Motorsport, Sport]  2023-04-30  14:48:07           441
# 4         0     6734  [Motorsport, Sport]  2023-05-07  21:36:45           484
# 5         0     5295  [Motorsport, Sport]  2023-05-28  16:07:17           484
# 6         0     5000  [Motorsport, Sport]  2023-06-04  15:29:51           484
# 7         0     4007  [Motorsport, Sport]  2023-06-18  20:41:35           485
# 8         0     4517  [Motorsport, Sport]  2023-07-02  15:44:49           492
# 9         0     4889  [Motorsport, Sport]  2023-07-09  16:08:10           488

# %%
# Use this to store it as a csv file if you want
# df.to_csv('Youtube_Data.csv', index=False)
